# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#项目介绍" data-toc-modified-id="项目介绍-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>项目介绍</a></span></li><li><span><a href="#导入库" data-toc-modified-id="导入库-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>导入库</a></span></li><li><span><a href="#读取文件考研历年国家分数线" data-toc-modified-id="读取文件考研历年国家分数线-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>读取文件考研历年国家分数线</a></span></li><li><span><a href="#处理重复值和空值" data-toc-modified-id="处理重复值和空值-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>处理重复值和空值</a></span></li><li><span><a href="#删除不需要的列" data-toc-modified-id="删除不需要的列-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>删除不需要的列</a></span></li><li><span><a href="#替换删除特殊字符" data-toc-modified-id="替换删除特殊字符-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>替换删除特殊字符</a></span></li><li><span><a href="#单独筛选出2020年考研信息" data-toc-modified-id="单独筛选出2020年考研信息-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>单独筛选出2020年考研信息</a></span></li><li><span><a href="#统计专业" data-toc-modified-id="统计专业-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>统计专业</a></span></li><li><span><a href="#分组归纳学校对应的专业数（专业可能是重复值）" data-toc-modified-id="分组归纳学校对应的专业数（专业可能是重复值）-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>分组归纳学校对应的专业数（专业可能是重复值）</a></span></li><li><span><a href="#转化考研专业总分特殊值" data-toc-modified-id="转化考研专业总分特殊值-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>转化考研专业总分特殊值</a></span></li><li><span><a href="#分组归纳各专业的最高分，最低分，平均分" data-toc-modified-id="分组归纳各专业的最高分，最低分，平均分-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>分组归纳各专业的最高分，最低分，平均分</a></span></li><li><span><a href="#绘制各专业分数的柱状图" data-toc-modified-id="绘制各专业分数的柱状图-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>绘制各专业分数的柱状图</a></span></li><li><span><a href="#绘制2020年考研专业Top50" data-toc-modified-id="绘制2020年考研专业Top50-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>绘制2020年考研专业Top50</a></span></li><li><span><a href="#绘制关键词云图" data-toc-modified-id="绘制关键词云图-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>绘制关键词云图</a></span></li><li><span><a href="#读取2021年考研调剂信息" data-toc-modified-id="读取2021年考研调剂信息-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>读取2021年考研调剂信息</a></span></li><li><span><a href="#转换学校属性类别" data-toc-modified-id="转换学校属性类别-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>转换学校属性类别</a></span></li><li><span><a href="#删除重复值" data-toc-modified-id="删除重复值-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>删除重复值</a></span></li><li><span><a href="#拼接调剂信息" data-toc-modified-id="拼接调剂信息-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>拼接调剂信息</a></span></li><li><span><a href="#查看缺失数据" data-toc-modified-id="查看缺失数据-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>查看缺失数据</a></span></li><li><span><a href="#发布时间对应的发布频次" data-toc-modified-id="发布时间对应的发布频次-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>发布时间对应的发布频次</a></span></li><li><span><a href="#调剂信息发布时间走势图" data-toc-modified-id="调剂信息发布时间走势图-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>调剂信息发布时间走势图</a></span><ul class="toc-item"><li><span><a href="#由于考研成绩是在2月底发布的，所以调剂发布学校也随着增多" data-toc-modified-id="由于考研成绩是在2月底发布的，所以调剂发布学校也随着增多-21.1"><span class="toc-item-num">21.1&nbsp;&nbsp;</span>由于考研成绩是在2月底发布的，所以调剂发布学校也随着增多</a></span></li></ul></li><li><span><a href="#绘制学校类别饼图" data-toc-modified-id="绘制学校类别饼图-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>绘制学校类别饼图</a></span></li><li><span><a href="#调剂信息发布数省份分布" data-toc-modified-id="调剂信息发布数省份分布-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>调剂信息发布数省份分布</a></span></li></ul></div>

# %% [markdown]
# ### 项目介绍
# * 数据来源 IT：2021年考研调剂信息 通过考研网站 + 百度百科 整理获取
# * 可视化主要使用 pyecharts

# %% [markdown]
# ### 导入库

# %%
import json
import requests
import pandas as pd 
import pyecharts.options as opts
from pyecharts.charts import *
from pyecharts.globals import ThemeType#设定主题
from pyecharts.commons.utils import JsCode
import chardet 
import jieba
import numpy as np

# %%
pip install pyecharts
# Out:
# Requirement already satisfied: pyecharts in c:\users\10942\appdata\local\anaconda3\lib\site-packages (2.0.5)
# Requirement already satisfied: jinja2 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from pyecharts) (3.1.3)
# Requirement already satisfied: prettytable in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from pyecharts) (3.10.0)
# Requirement already satisfied: simplejson in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from pyecharts) (3.19.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from jinja2->pyecharts) (2.1.3)
# Requirement already satisfied: wcwidth in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from prettytable->pyecharts) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jieba
# Out:
# Requirement already satisfied: jieba in c:\users\10942\appdata\local\anaconda3\lib\site-packages (0.42.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 读取文件考研历年国家分数线

# %%
df1 = pd.read_csv(r'./考研历年国家分数线(1).csv')
df2 = pd.read_csv(r'./考研历年国家分数线(2).csv')
df3 = pd.read_csv(r'./考研历年国家分数线(3).csv')
df4 = pd.read_csv(r'./考研历年国家分数线(4).csv')
df5 = pd.read_csv(r'./考研历年国家分数线(5).csv')
df6 = pd.read_csv(r'./考研历年国家分数线(6).csv')
df_all= pd.concat([df1,df2,df3,df4,df5,df6])
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100864 entries, 0 to 863
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   年份       100864 non-null  int64
#  1   学校名称_链接  100864 non-null  object
#  2   学校名称     100863 non-null  object
#  3   院系名称_链接  100864 non-null  object
#  4   院系名称     100725 non-null  object
#  5   专业代码     100761 non-null  object
#  6   专业名称_链接  100864 non-null  object
#  7   专业名称     100864 non-null  object
#  8   总分       100864 non-null  object
#  9   政治__管综   100864 non-null  object
#  10  外语       100864 non-null  object
#  11  业务课_一    100864 non-null  object
#  12  业务课_二    100864 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 10.8+ MB

# %%
print(df_all.shape)
# Out:
# (100864, 13)

# %% [markdown]
# ### 处理重复值和空值

# %%
print('重复值：' ,df_all.duplicated().sum())
print('空值: \n',df_all.isnull().sum())
# Out:
# 重复值： 58
# 空值:
#  年份           0
# 学校名称_链接      0
# 学校名称         1
# 院系名称_链接      0
# 院系名称       139
# 专业代码       103
# 专业名称_链接      0
# 专业名称         0
# 总分           0
# 政治__管综       0
# 外语           0
# 业务课_一        0
# 业务课_二        0
# dtype: int64

# %%
df_all = df_all.drop_duplicates()
df_all = df_all.dropna(axis=0,how='any')

# %%
df_all.info()
print(df_all.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100563 entries, 0 to 863
# Data columns (total 13 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   年份       100563 non-null  int64
#  1   学校名称_链接  100563 non-null  object
#  2   学校名称     100563 non-null  object
#  3   院系名称_链接  100563 non-null  object
#  4   院系名称     100563 non-null  object
#  5   专业代码     100563 non-null  object
#  6   专业名称_链接  100563 non-null  object
#  7   专业名称     100563 non-null  object
#  8   总分       100563 non-null  object
#  9   政治__管综   100563 non-null  object
#  10  外语       100563 non-null  object
#  11  业务课_一    100563 non-null  object
#  12  业务课_二    100563 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 10.7+ MB
# (100563, 13)

# %%
print('重复值：' ,df_all.duplicated().sum())
print('空值: \n',df_all.isnull().sum())
# Out:
# 重复值： 0
# 空值:
#  年份         0
# 学校名称_链接    0
# 学校名称       0
# 院系名称_链接    0
# 院系名称       0
# 专业代码       0
# 专业名称_链接    0
# 专业名称       0
# 总分         0
# 政治__管综     0
# 外语         0
# 业务课_一      0
# 业务课_二      0
# dtype: int64

# %% [markdown]
# ### 删除不需要的列

# %%
df_all = df_all.drop(labels=['学校名称_链接','院系名称_链接','专业名称_链接'],axis=1)
df_all.head(2)
# Out:
#      年份    学校名称    院系名称    专业代码        专业名称   总分 政治__管综  外语 业务课_一 业务课_二
# 0  2020  中国人民大学  公共管理学院  125200  (专业学位)公共管理  175     88  44     -     -
# 1  2020  中国人民大学  公共管理学院  125200  (专业学位)公共管理  175     88  44     -     -

# %% [markdown]
# ### 替换删除特殊字符

# %%
df_all['专业名称'] = df_all['专业名称'].str.replace('\(专业学位\)','')
df_all['专业名称'] = df_all['专业名称'].str.replace('★','')
df_all.head(2)
# Out:
#      年份    学校名称    院系名称    专业代码        专业名称   总分 政治__管综  外语 业务课_一 业务课_二
# 0  2020  中国人民大学  公共管理学院  125200  (专业学位)公共管理  175     88  44     -     -
# 1  2020  中国人民大学  公共管理学院  125200  (专业学位)公共管理  175     88  44     -     -

# %% [markdown]
# ### 单独筛选出2020年考研信息

# %%
data_2020 = df_all[df_all['年份'] == 2020]
data_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65808 entries, 0 to 5995
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   年份      65808 non-null  int64
#  1   学校名称    65808 non-null  object
#  2   院系名称    65808 non-null  object
#  3   专业代码    65808 non-null  object
#  4   专业名称    65808 non-null  object
#  5   总分      65808 non-null  object
#  6   政治__管综  65808 non-null  object
#  7   外语      65808 non-null  object
#  8   业务课_一   65808 non-null  object
#  9   业务课_二   65808 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 5.5+ MB

# %% [markdown]
# ### 统计专业

# %%
data_2020['专业名称'].value_counts()[:100]
# Out:
# 专业名称
# 计算机科学与技术      877
# 管理科学与工程       844
# 数学            808
# 机械工程          687
# 控制科学与工程       680
#              ...
# 计算机应用技术       178
# (专业学位)应用心理    178
# 网络空间安全        177
# 中西医结合临床       175
# 艺术学理论         173
# Name: count, Length: 100, dtype: int64

# %% [markdown]
# ### 分组归纳学校对应的专业数（专业可能是重复值）

# %%
data_2020.groupby('学校名称')['专业名称'].count().sort_values(ascending = False)[:100]
# Out:
# 学校名称
# 北京大学      3093
# 复旦大学      1248
# 清华大学      1217
# 武汉大学       858
# 中国人民大学     758
#           ...
# 河南科技大学     211
# 华北理工大学     208
# 上海师范大学     207
# 吉林农业大学     205
# 沈阳农业大学     203
# Name: 专业名称, Length: 100, dtype: int64

# %% [markdown]
# ### 转化考研专业总分特殊值

# %%
def tranform_num(x):
    if '-' in x:
        return 0
    else:
        return x
    
data_2020['总分'] = data_2020['总分'].apply(lambda x:tranform_num(x) )
data_2020['总分'] = data_2020['总分'].astype('int')
# Out:
# C:\Users\10942\AppData\Local\Temp\ipykernel_13112\688768844.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020['总分'] = data_2020['总分'].apply(lambda x:tranform_num(x) )
# C:\Users\10942\AppData\Local\Temp\ipykernel_13112\688768844.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2020['总分'] = data_2020['总分'].astype('int')

# %% [markdown]
# ### 分组归纳各专业的最高分，最低分，平均分

# %%
data_1 = data_2020.groupby('专业名称')['总分'].agg([np.mean, np.max,np.min])
data_1['mean'] = data_1['mean'].astype('int')
data_1 = data_1.sort_values(by=['mean'],ascending=False)[:50]
data_1
# Out:
# C:\Users\10942\AppData\Local\Temp\ipykernel_13112\598740315.py:1: FutureWarning: The provided callable <function mean at 0x0000015C0108F7E0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   data_1 = data_2020.groupby('专业名称')['总分'].agg([np.mean, np.max,np.min])
# C:\Users\10942\AppData\Local\Temp\ipykernel_13112\598740315.py:1: FutureWarning: The provided callable <function max at 0x0000015C0108EDE0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data_1 = data_2020.groupby('专业名称')['总分'].agg([np.mean, np.max,np.min])
# C:\Users\10942\AppData\Local\Temp\ipykernel_13112\598740315.py:1: FutureWarning: The provided callable <function min at 0x0000015C0108EF20> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data_1 = data_2020.groupby('专业名称')['总分'].agg([np.mean, np.max,np.min])
#                 mean  max  min
# 专业名称
# 公共关系学            409  409  409
# 国别与区域研究          402  402  402
# 美术理论研究           397  397  397
# 信息艺术设计           390  390  390
# 国民经济动员学          388  400  376
# 高级秘书与行政助理学       386  386  386
# 公共组织与人力资源        385  385  385
# 中国政治             383  383  383
# 网络与新媒体           382  382  382
# 符号学              382  382  382
# 传媒艺术学            381  381  381
# 媒介管理学            380  380  380
# 公共财政与公共政策        380  380  380
# 非传统安全            380  380  380
# 政府经济管理           379  379  379
# 地方政府与社会治理        377  377  377
# 电子政务             376  380  360
# 公共管理信息化理论与技术     375  375  375
# 能源与气候经济          375  376  375
# 城乡发展与规划          375  375  375
# 犯罪心理学            375  375  375
# 文化研究             372  378  355
# 医院管理与卫生政策        372  372  372
# 物流管理与工程          372  372  372
# 文化传播学            370  370  370
# 电视电影与视听传播学       370  370  370
# 互联网金融学           370  370  370
# 医药信息系统           370  370  370
# 艺术与科学            370  370  370
# 创业学              370  370  370
# 军事法学             370  370  370
# 法与经济学            370  370  370
# 饭店管理             370  370  370
# 网络经济学            368  368  368
# 企业经济学            368  368  368
# 话语与传播            368  368  368
# 财务学              368  370  365
# 对外汉语教学           368  370  365
# 广播电视学            367  380  355
# 金融统计、保险精算与风险管理   367  367  367
# 写作学              365  365  365
# 比较法学             365  365  365
# 文化资源与文化产业        365  365  365
# 新媒体              365  365  365
# 信息分析             365  365  365
# 艺术史论             365  365  365
# 广告学              365  380  355
# 党的历史与理论          365  365  365
# 市场营销管理           365  365  365
# 中国画              365  365  365

# %% [markdown]
# ### 绘制各专业分数的柱状图

# %%
data_1.keys()
# Out:
# Index(['mean', 'max', 'min'], dtype='object')

# %%
bar1 = Bar(init_opts=opts.InitOpts(theme='light',
                                    width='1000px',
                                    height='1200px')
                                    )

bar1.add_xaxis(data_1.index.tolist())
bar1.add_yaxis('最高分', 
               data_1['max'].tolist(),
               z_level=1,
               stack='1',
               category_gap='50%',
               tooltip_opts=opts.TooltipOpts(is_show=False),
               label_opts=opts.LabelOpts(position='insideRight', formatter='{c} 分'),
               itemstyle_opts={"normal": {
                        'shadowBlur': 10,
                        'shadowColor': 'rgba(0, 0, 0, 0.1)',
                        'shadowOffsetX': 10,
                        'shadowOffsetY': 10,
                        'color':'#ec9bad',
                        'borderColor': 'rgb(220,220,220)',
                        'borderWidth':2}
                },
               )
bar1.add_yaxis('最低分', 
               data_1['min'].tolist(),
               z_level=1,
               stack='1',
               category_gap='50%',
               tooltip_opts=opts.TooltipOpts(is_show=False),
               label_opts=opts.LabelOpts(position='insideLeft', formatter='{c} 分'),
               itemstyle_opts={"normal": {
                        'shadowBlur': 10,
                        'shadowColor': 'rgba(0, 0, 0, 0.1)',
                        'shadowOffsetX': 10,
                        'shadowOffsetY': 10,
                        'color':'#87CEFA',
                        'borderColor': 'rgb(220,220,220)',
                        'borderWidth':2}
                },
               )


bar1.set_global_opts(title_opts=opts.TitleOpts(title="各专业的最高分和最低分",
                                              pos_left="center",
                                              pos_top='0%',
                                              title_textstyle_opts=opts.TextStyleOpts(font_size=20,
                                                                                      color='#00BFFF')),
                        legend_opts=opts.LegendOpts(is_show=True, pos_top='3%'),
                        datazoom_opts=opts.DataZoomOpts(type_='inside',
                                                    range_start=50,   # 设置起止位置，50%-100%
                                                    range_end=100,
                                                    orient='vertical'),
                        xaxis_opts=opts.AxisOpts(is_show=False, max_=818),
                        yaxis_opts=opts.AxisOpts(axisline_opts=opts.AxisLineOpts(is_show=False),
                                             axistick_opts=opts.AxisTickOpts(is_show=False),
                                             axislabel_opts=opts.LabelOpts(color='#528B8B', font_size=10, font_weight='bold')),
                    )
bar1.reversal_axis()
bar1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c74b104bda604c4896f6644a6272918c" style="width:1000px; height:1200px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c74b104bda604c4896f6644a6272918c = echarts.init(
#                     document.getElementById('c74b104bda604c4896f6644a6272918c'), 'light', {renderer: 'canvas'});
#                 var option_c74b104bda604c4896f6644a6272918c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u6700\u9ad8\u5206",
#             "legendHoverLink": true,
#             "data": [
#                 409,
#                 402,
#                 397,
#                 390,
#                 400,
#                 386,
#                 385,
#                 383,
#                 382,
#                 382,
#                 381,
#                 380,
#                 380,
#                 380,
#                 379,
#                 377,
#                 380,
#                 375,
#                 376,
#                 375,
#                 375,
#                 378,
#                 372,
#                 372,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 368,
#                 368,
#                 368,
#                 370,
#                 370,
#                 380,
#                 367,
#                 365,
#                 365,
#                 365,
#                 365,
#                 365,
#                 365,
#                 380,
#                 365,
#                 365,
#                 365
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "50%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 1,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "insideRight",
#                 "margin": 8,
#                 "formatter": "{c} \u5206"
#             },
#             "tooltip": {
#                 "show": false,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "enterable": false,
#                 "confine": false,
#                 "appendToBody": false,
#                 "transitionDuration": 0.4,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5,
#                 "order": "seriesAsc"
#             },
#             "itemStyle": {
#                 "normal": {
#                     "shadowBlur": 10,
#                     "shadowColor": "rgba(0, 0, 0, 0.1)",
#                     "shadowOffsetX": 10,
#                     "shadowOffsetY": 10,
#                     "color": "#ec9bad",
#                     "borderColor": "rgb(220,220,220)",
#                     "borderWidth": 2
#                 }
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6700\u4f4e\u5206",
#             "legendHoverLink": true,
#             "data": [
#                 409,
#                 402,
#                 397,
#                 390,
#                 376,
#                 386,
#                 385,
#                 383,
#                 382,
#                 382,
#                 381,
#                 380,
#                 380,
#                 380,
#                 379,
#                 377,
#                 360,
#                 375,
#                 375,
#                 375,
#                 375,
#                 355,
#                 372,
#                 372,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 370,
#                 368,
#                 368,
#                 368,
#                 365,
#                 365,
#                 355,
#                 367,
#                 365,
#                 365,
#                 365,
#                 365,
#                 365,
#                 365,
#                 355,
#                 365,
#                 365,
#                 365
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stack": "1",
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "50%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 1,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "insideLeft",
#                 "margin": 8,
#                 "formatter": "{c} \u5206"
#             },
#             "tooltip": {
#                 "show": false,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "enterable": false,
#                 "confine": false,
#                 "appendToBody": false,
#                 "transitionDuration": 0.4,
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5,
#                 "order": "seriesAsc"
#             },
#             "itemStyle": {
#                 "normal": {
#                     "shadowBlur": 10,
#                     "shadowColor": "rgba(0, 0, 0, 0.1)",
#                     "shadowOffsetX": 10,
#                     "shadowOffsetY": 10,
#                     "color": "#87CEFA",
#                     "borderColor": "rgb(220,220,220)",
#                     "borderWidth": 2
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6700\u9ad8\u5206",
#                 "\u6700\u4f4e\u5206"
#             ],
#             "selected": {},
#             "show": true,
#             "top": "3%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay

# %%
data_2 = data_2020['专业名称'].value_counts()[:50]

# %% [markdown]
# ### 绘制2020年考研专业Top50

# %%
from pyecharts.charts import Scatter
from pyecharts import options as opts

# %%
from pyecharts.charts import Pie
from pyecharts import options as opts

data_x = data_2.index.tolist()
data_y = data_2.values.tolist()

pie_chart = Pie(init_opts=opts.InitOpts(theme='light', width='1000px', height='900px'))
pie_chart.add("", [list(z) for z in zip(data_x, data_y)], radius=["30%", "60%"])  # 添加数据，并设置内外半径
pie_chart.set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}个"))  # 设置标签格式
pie_chart.set_global_opts(title_opts=opts.TitleOpts(title="2020年考研专业Top50", 
                                                    pos_top='2%', 
                                                    pos_left='center', 
                                                    title_textstyle_opts=opts.TextStyleOpts(font_size=20, color='#00BFFF')),
                          legend_opts=opts.LegendOpts(is_show=False),
                          visualmap_opts=opts.VisualMapOpts(is_show=False, 
                                                            max_=1058,
                                                            min_=1,
                                                            is_piecewise=False,
                                                            dimension=0,
                                                            range_color=['rgba(135,206,235,1)', 'rgba(70,130,18,0.4)',])
                         )
pie_chart.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2b5bc57afb1245cea7831f5759ff4c06" style="width:1000px; height:900px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2b5bc57afb1245cea7831f5759ff4c06 = echarts.init(
#                     document.getElementById('2b5bc57afb1245cea7831f5759ff4c06'), 'light', {renderer: 'canvas'});
#                 var option_2b5bc57afb1245cea7831f5759ff4c06 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u8ba1\u7b97\u673a\u79d1\u5b66\u4e0e\u6280\u672f",
#                     "value": 877
#                 },
#                 {
#                     "name": "\u7ba1\u7406\u79d1\u5b66\u4e0e\u5de5\u7a0b",
#                     "value": 844
#                 },
#                 {
#                     "name": "\u6570\u5b66",
#                     "value": 808
#                 },
#                 {
#                     "name": "\u673a\u68b0\u5de5\u7a0b",
#                     "value": 687
#                 },
#                 {
#                     "name": "\u63a7\u5236\u79d1\u5b66\u4e0e\u5de5\u7a0b",
#                     "value": 680
#                 },
#                 {
#                     "name": "\u6750\u6599\u79d1\u5b66\u4e0e\u5de5\u7a0b",
#                     "value": 675
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u5de5\u5546\u7ba1\u7406",
#                     "value": 650
#                 },
#                 {
#                     "name": "\u9a6c\u514b\u601d\u4e3b\u4e49\u7406\u8bba",
#                     "value": 623
#                 },
#                 {
#                     "name": "\u5316\u5b66",
#                     "value": 581
#                 },
#                 {
#                     "name": "\u7269\u7406\u5b66",
#                     "value": 568
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u4f1a\u8ba1",
#                     "value": 565
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u827a\u672f\u8bbe\u8ba1",
#                     "value": 560
#                 },
#                 {
#                     "name": "\u8bbe\u8ba1\u5b66",
#                     "value": 554
#                 },
#                 {
#                     "name": "\u751f\u7269\u5b66",
#                     "value": 530
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u4e0e\u901a\u4fe1\u5de5\u7a0b",
#                     "value": 526
#                 },
#                 {
#                     "name": "\u5316\u5b66\u5de5\u7a0b\u4e0e\u6280\u672f",
#                     "value": 501
#                 },
#                 {
#                     "name": "\u571f\u6728\u5de5\u7a0b",
#                     "value": 465
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u91d1\u878d",
#                     "value": 461
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u97f3\u4e50",
#                     "value": 459
#                 },
#                 {
#                     "name": "\u73af\u5883\u79d1\u5b66\u4e0e\u5de5\u7a0b",
#                     "value": 459
#                 },
#                 {
#                     "name": "\u8f6f\u4ef6\u5de5\u7a0b",
#                     "value": 457
#                 },
#                 {
#                     "name": "\u5e94\u7528\u7ecf\u6d4e\u5b66",
#                     "value": 444
#                 },
#                 {
#                     "name": "\u7edf\u8ba1\u5b66",
#                     "value": 440
#                 },
#                 {
#                     "name": "\u7f8e\u672f\u5b66",
#                     "value": 426
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u7f8e\u672f",
#                     "value": 420
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u516c\u5171\u7ba1\u7406",
#                     "value": 418
#                 },
#                 {
#                     "name": "\u5185\u79d1\u5b66",
#                     "value": 413
#                 },
#                 {
#                     "name": "\u5de5\u5546\u7ba1\u7406",
#                     "value": 408
#                 },
#                 {
#                     "name": "\u97f3\u4e50\u4e0e\u821e\u8e48\u5b66",
#                     "value": 403
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u53f2",
#                     "value": 402
#                 },
#                 {
#                     "name": "\u7535\u6c14\u5de5\u7a0b",
#                     "value": 398
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u5185\u79d1\u5b66",
#                     "value": 395
#                 },
#                 {
#                     "name": "\u6cd5\u5b66",
#                     "value": 379
#                 },
#                 {
#                     "name": "\u4f01\u4e1a\u7ba1\u7406",
#                     "value": 375
#                 },
#                 {
#                     "name": "\u7535\u5b50\u79d1\u5b66\u4e0e\u6280\u672f",
#                     "value": 372
#                 },
#                 {
#                     "name": "\u52a8\u529b\u5de5\u7a0b\u53ca\u5de5\u7a0b\u70ed\u7269\u7406",
#                     "value": 364
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u836f\u5b66",
#                     "value": 363
#                 },
#                 {
#                     "name": "\u5149\u5b66\u5de5\u7a0b",
#                     "value": 363
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u6cd5\u5f8b\uff08\u975e\u6cd5\u5b66\uff09",
#                     "value": 348
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u6cd5\u5f8b\uff08\u6cd5\u5b66\uff09",
#                     "value": 344
#                 },
#                 {
#                     "name": "\u751f\u7269\u533b\u5b66\u5de5\u7a0b",
#                     "value": 340
#                 },
#                 {
#                     "name": "\u4f1a\u8ba1\u5b66",
#                     "value": 330
#                 },
#                 {
#                     "name": "\u91d1\u878d\u5b66",
#                     "value": 328
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u793e\u4f1a\u5de5\u4f5c",
#                     "value": 311
#                 },
#                 {
#                     "name": "\u601d\u60f3\u653f\u6cbb\u6559\u80b2",
#                     "value": 309
#                 },
#                 {
#                     "name": "(\u4e13\u4e1a\u5b66\u4f4d)\u5e94\u7528\u7edf\u8ba1",
#                     "value": 304
#                 },
#                 {

# %% [markdown]
# ### 绘制关键词云图

# %%
def get_cut_words(content_series):
    # 读入停用词表
    stop_words = [' ','是','的'] 

#     with open(r"\中文停用词库.txt", 'r') as f:
#         lines = f.readlines()
#         for line in lines:
#             stop_words.append(line.strip())

    # 添加关键词
    my_words = ['']      
    for i in my_words:
        jieba.add_word(i) 

    # 自定义停用词
    my_stop_words = ['查看','详细','详见','详情','与化','03','02','01','正文','多个','相关']    
    stop_words.extend(my_stop_words)               

    # 分词
    word_num = jieba.lcut(content_series.str.cat(sep='。'), cut_all=False)

    # 条件筛选
    word_num_selected = [i for i in word_num if i not in stop_words and len(i)>=2]
    
    return word_num_selected

# %%
text1 = get_cut_words(content_series=df_all.专业名称)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\10942\AppData\Local\Temp\jieba.cache
# Loading model cost 0.894 seconds.
# Prefix dict has been built successfully.

# %%
# 安装stylecloud
# !pip install stylecloud  -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: stylecloud in c:\users\10942\appdata\local\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: wordcloud in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from stylecloud) (1.9.3)
# Requirement already satisfied: icon-font-to-png in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from stylecloud) (0.4.1)
# Requirement already satisfied: palettable in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from stylecloud) (3.3.3)
# Requirement already satisfied: fire in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from stylecloud) (0.6.0)
# Requirement already satisfied: matplotlib in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from stylecloud) (3.8.0)
# Requirement already satisfied: six in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from fire->stylecloud) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from fire->stylecloud) (2.4.0)
# Requirement already satisfied: Pillow>=4.0.0 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from icon-font-to-png->stylecloud) (10.2.0)
# Requirement already satisfied: requests>=2.12.5 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from icon-font-to-png->stylecloud) (2.31.0)
# Requirement already satisfied: tinycss>=0.4 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from icon-font-to-png->stylecloud) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from matplotlib->stylecloud) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2024.2.2)

# %%
from pyecharts import options as opts
from pyecharts.charts import WordCloud

words = [
    ("北京大学", 1446),
    ("清华大学", 1336),
    ("南开大学", 906),
    ("北京理工大学", 825),
    ("福州大学", 777),
    ("武汉大学", 734),
    ("安徽大学", 688),
    ("武汉理工大学", 683),
    ("苏州大学", 86),
    ("天津师范大学", 17),
    ("中央名族大学", 6),
    ("宁夏大学", 1),
    ("东北大学", 64),
    ("四川大学", 422),
    ("河北大学", 353),
    ("郑州大学", 331),
    ("中国农业大学", 313),
    ("中南大学", 307),
    ("中国矿业大学", 43),
    ("南京大学", 15),
    ("海南大学", 438),
    ("西北农林科技大学", 957),
    ("华南理工大学", 927),
    ("华东师范大学", 908),
    ("复旦大学", 693),
    ("中山大学", 611),
    ("北京中医药大学", 512),
    ("河南大学", 382),
    ("山西大学", 312),
    ("南京航空航天大学", 187),
    ("对外经济贸易大学", 163),
    ("佳木斯大学", 104),
    ("中国政法大学", 3),
    ("上海师范大学", 1331),
    ("哈尔滨工程大学", 941),
    ("上海大学", 585),
    ("云南大学", 473),
    ("河北师范大学", 358),
    ("大连海事大学", 246),
    ("中国医科大学", 207),
    ("江西财经大学", 194),
    ("兰州大学", 104),
    ("吉林大学", 87),
    ("南昌大学", 63),
    ("上海理工大学", 48),
    ("河北师范大学", 23),
    ("湖南师范大学", 5),
    ("河北农行大学", 1328),
    ("宁波大学", 765),
    ("华中科技大学", 452),
    ("华中农业大学", 415),
    ("长江大学", 253),
    ("南京师范大学", 211),
    ("中南财经政法大学", 180),
    ("汕头大学", 138),
    ("厦门大学", 116),
    ("中央美术学院", 98),
    ("北京邮电大学", 93),
    ("青岛大学", 92),
    ("北京工商大学", 90),
    ("中国人民大学", 76),
    ("北京工业大学", 76),
    ("北方工业大学", 40),
    ("北京建筑大学", 36),
    ("北京电子科技学院", 30),
    ("北京农学院", 7),
    ("北京林业大学", 1),
    ("北京石油化工学院", 1309),
    ("北京印刷学院", 965),
    ("北京协和医学院", 900),
    ("北京语言大学", 727),
    ("外交学院", 461),
    ("中央音乐学院", 309),
    ("北京体育大学", 260),
    ("中国人民公安大学", 173),
    ("中国传媒大学", 155),
    ("首都体育学院", 136),
    ("中央美术学院", 121),
    ("中国戏曲学院", 76),
    ("中国政法大学", 62),
    ("北京城市学院", 37),
    ("中国社会科学院大学", 32),
    ("长江商学院", 28),
    ("北京联合大学", 4),
    ("华北电力大学", 1275),
    ("中央民族大学", 1088),
    ("北京电影学院", 907),
    ("中央戏剧学院", 837),
    ("国防大学", 201),
    ("天津中医药大学", 195),
    ("天津商业大学", 179),
    ("天津美术学院", 119),
    ("天津城建大学", 43),
    ("天津财经大学", 1234),
    ("河北工程大学", 802),
    ("河北地质大学", 405),
    ("河北师范大学", 337),
    ("河北经贸大学", 199),
    ("河北传媒学院", 78),
    ("太原科技大学", 77),
    ("太原理工大学", 36),
    ("山西医科大学", 29),
    ("山西大同大学", 3),
    ("山西财经大学", 1201),
    ("太原实弹学院", 508),
    ("中北大学", 147),
    ("内蒙古大学", 125),
    ("内蒙古科技大学", 115),
    ("内蒙古农业大学", 101),
    ("内蒙古师范大学", 66),
    ("内蒙古工业大学", 32),
    ("内蒙古医科大学", 22),
    ("辽宁大学", 9),
    ("沈阳理工大学", 8),
    ("沈阳工业大学", 2),
    ("沈阳建筑大学", 2),
    ("沈阳农业大学", 1),
    ("辽宁师范大学", 1169),
    ("沈阳医科大学", 412),
    ("大连工业大学", 393),
    ("大连交通大学", 230),
    ("辽宁石油化工大学", 211),
    ("辽宁科技大学", 207),
    ("渤海大学", 139),
    ("沈阳大学", 75),
    ("沈阳体育学院", 23),
    ("大连民族大学", 21),
    ("长春理工大学", 17),
    ("长春工业大学", 6),
    ("吉林化工学院", 5),
    ("吉林财经大学", 4),
    ("长春大学", 1),
    ("延边大学", 1),
    ("东北林业大学", 1),
    ("同济大学", 11),
    ("上海海事大学", 85),
    ("东华大学", 543),
    ("上海工程科技大学", 321),
    ("上海戏剧学院", 253),
    ("上海商学院", 162),
    ("南京邮电大学", 149),
    ("江南大学", 133),
    ("河海大学", 113),
    ("常州大学", 67),
    ("徐州医科大学", 54),
    ("扬州大学", 45),
    ("南京审计大学", 22),
    ("杭州电子科技大学", 1047),
    ("浙江理工大学", 566),
    ("温州医科大学", 289),
    ("浙江师范大学", 184),
    ("浙江工商大学", 168),
    ("浙江财经大学", 137),
    ("西湖大学", 1041),
    ("安徽理工大学", 505),
    ("安徽工业大学", 299),
    ("安徽师范大学", 103),
    ("安徽医科大学", 66),
    ("安徽工程大学", 41),
    ("福建中医药大学", 271),
    ("福建理工大学", 30),
    ("闽南师范大学", 25),
    ("南昌大学", 16),
    ("江西理工大学", 15),
    ("江西农业大学", 12),
    ("山东大学", 9),
    ("山东科技大学", 8),
    ("山东农业大学", 1),
    ("山东理工大学", 1),
    ("山东师范大学", 1018),
    ("山东财经大学", 896),
    ("临沂大学", 440),
    ("河南理工大学", 365),
    ("河南工业大学", 256),
    ("河南科技大学", 214),
    ("信阳师范大学", 39),
    ("河南财经政法大学", 28),
    ("信息工程大学", 23),
    ("武汉轻工大学", 814),
    ("湖北工业大学", 946),
    ("华中师范大学", 1765),
    ("湖北大学", 353),
    ("湖北中医药大学", 254),
    ("武汉纺织大学", 1888),
    ("武汉工程大学", 766),
    ("武汉科技大学", 1942),
    ("中国地质大学", 877),
    ("黄冈师范学院", 133),
    ("湖北民族大学", 580),
    ("湖北美术学院", 450),
    ("湖北汽车工业学院", 346),
    ("三峡大学", 26),
    ("湖北经济学院", 21),
    ("湖北文理学院", 914),
    ("武汉体育学院", 311),
    ("中南民族大学", 257),
    ("江汉大学", 131),
    ("湘潭大学", 125),
    ("吉首大学", 122),
    ("长沙理工大学", 81),
    ("湖南科技大学", 67),
    ("湖南师范大学", 41),
    ("南华大学", 26),
    ("湖南工商大学", 913),
    ("暨南大学", 483),
    ("华南理工大学", 128),
    ("广东海洋大学", 105),
    ("广东医科大学", 77),
    ("广东药科大学", 22),
    ("肇庆学院", 107),
    ("深圳大学", 644),
    ("广东财经大学", 273),
    ("东莞理工学院", 187),
    ("五邑大学", 140),
    ("广东工业大学", 107),
    ("南方医科大学", 47),
    ("广西科技大学", 43),
    ("桂林理工大学", 29),
    ("南宁师范大学", 10),
    ("广西师范大学", 83),
    ("广西民族大学", 536),
    ("重庆师范大学", 108),
    ("重庆文理学院", 49),
    ("西南政法大学", 38),
    ("重庆工商大学", 37),
    ("重庆理工大学", 24),
    ("四川大学", 24),
    ("电子科技大学", 3),
    ("成都理工大学", 3),
    ("四川轻化工大学", 13),
    ("西华师范大学", 874),
    ("贵州大学", 363),
    ("贵州医科大学", 162),
    ("贵州民族大学", 50),
    ("昆明理工大学", 21),
    ("云南大学", 20),
    ("大理大学", 16),
    ("云南财经大学", 10),
    ("云南民族大学", 89),
    ("西藏民族大学", 16),
    ("西北工业大学", 303),
    ("西安科技大学", 196),
    ("西安工业大学", 93),
    ("陕西理工大学", 47),
    ("陕西师范大学", 32),
    ("宁夏医科大学", 90),
]

c = (
    WordCloud()
    .add("",
     words, 
     word_size_range=[6, 20], 
        # 单词间隔
    word_gap = 20,


    # 旋转单词角度
    rotate_step = 45,

    # 距离左侧的距离 types.Optional[str]
    pos_left = None,

    # 距离顶部的距离
    pos_top = None,

    # 距离右侧的距离
    pos_right= None,

    # 距离底部的距离
    pos_bottom = None,

    # 词云图的宽度
    width = None,

    # 词云图的高度
    height = None,

    # 允许词云图的数据展示在画布范围之外
    is_draw_out_of_bound = False,

    
    textstyle_opts=opts.TextStyleOpts(font_family="cursive"),

     # 将图片放在指定位置，然后读取
	 mask_image='D:/ss.png')
    .set_global_opts(title_opts=opts.TitleOpts(title="报考学院词云图"))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="6caf14b0273b4f3c85d0db015175cc17" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_6caf14b0273b4f3c85d0db015175cc17 = echarts.init(
#                     document.getElementById('6caf14b0273b4f3c85d0db015175cc17'), 'white', {renderer: 'canvas'});
#
#         var maskImage_53b65972a5b440b0a0ddc9f4bdc4157a = new Image();
#         maskImage_53b65972a5b440b0a0ddc9f4bdc4157a.src = 'data:image/png;base64,...';
#
#                 var option_6caf14b0273b4f3c85d0db015175cc17 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "maskImage": maskImage_53b65972a5b440b0a0ddc9f4bdc4157a,
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 6,
#                 20
#             ],
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5927\u5b66",
#                     "value": 1446,
#                     "textStyle": {
#                         "color": "rgb(42,126,111)"
#                     }
#                 },
#                 {
#                     "name": "\u6e05\u534e\u5927\u5b66",
#                     "value": 1336,
#                     "textStyle": {
#                         "color": "rgb(160,35,34)"
#                     }
#                 },
#                 {
#                     "name": "\u5357\u5f00\u5927\u5b66",
#                     "value": 906,
#                     "textStyle": {
#                         "color": "rgb(128,71,0)"
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u7406\u5de5\u5927\u5b66",
#                     "value": 825,
#                     "textStyle": {
#                         "color": "rgb(42,45,119)"
#                     }
#                 },
#                 {
#                     "name": "\u798f\u5dde\u5927\u5b66",
#                     "value": 777,
#                     "textStyle": {
#                         "color": "rgb(41,157,150)"
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u6c49\u5927\u5b66",
#                     "value": 734,
#                     "textStyle": {
#                         "color": "rgb(101,133,65)"
#                     }
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u5927\u5b66",
#                     "value": 688,
#                     "textStyle": {
#                         "color": "rgb(51,139,69)"
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u6c49\u7406\u5de5\u5927\u5b66",
#                     "value": 683,
#                     "textStyle": {
#                         "color": "rgb(32,115,159)"
#                     }
#                 },
#                 {
#                     "name": "\u82cf\u5dde\u5927\u5b66",
#                     "value": 86,
#                     "textStyle": {
#                         "color": "rgb(110,88,19)"
#                     }
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e08\u8303\u5927\u5b66",
#                     "value": 17,
#                     "textStyle": {
#                         "color": "rgb(97,105,105)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u592e\u540d\u65cf\u5927\u5b66",
#                     "value": 6,
#                     "textStyle": {
#                         "color": "rgb(72,1,18)"
#                     }
#                 },
#                 {
#                     "name": "\u5b81\u590f\u5927\u5b66",
#                     "value": 1,
#                     "textStyle": {
#                         "color": "rgb(43,141,66)"
#                     }
#                 },
#                 {
#                     "name": "\u4e1c\u5317\u5927\u5b66",
#                     "value": 64,
#                     "textStyle": {
#                         "color": "rgb(129,108,94)"
#                     }
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u5927\u5b66",
#                     "value": 422,
#                     "textStyle": {
#                         "color": "rgb(122,77,104)"
#                     }
#                 },
#                 {
#                     "name": "\u6cb3\u5317\u5927\u5b66",
#                     "value": 353,
#                     "textStyle": {
#                         "color": "rgb(30,4,65)"
#                     }
#                 },
#                 {
#                     "name": "\u90d1\u5dde\u5927\u5b66",
#                     "value": 331,
#                     "textStyle": {
#                         "color": "rgb(111,91,131)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u519c\u4e1a\u5927\u5b66",
#                     "value": 313,
#                     "textStyle": {
#                         "color": "rgb(115,116,59)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5357\u5927\u5b66",
#                     "value": 307,
#                     "textStyle": {
#                         "color": "rgb(141,134,64)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u56fd\u77ff\u4e1a\u5927\u5b66",
#                     "value": 43,
#                     "textStyle": {
#                         "color": "rgb(100,14,115)"
#                     }
#                 },
#                 {
#                     "name": "\u5357\u4eac\u5927\u5b66",
#                     "value": 15,
#                     "textStyle": {
#                         "color": "rgb(36,148,43)"
#                     }
#                 },
#                 {
#                     "name": "\u6d77\u5357\u5927\u5b66",
#                     "value": 438,
#                     "textStyle": {
#                         "color": "rgb(73,118,156)"
#                     }
#                 },
#                 {
#                     "name": "\u897f\u5317\u519c\u6797\u79d1\u6280\u5927\u5b66",
#                     "value": 957,
#                     "textStyle": {
#                         "color": "rgb(146,17,12)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u5357\u7406\u5de5\u5927\u5b66",
#                     "value": 927,
#                     "textStyle": {
#                         "color": "rgb(26,79,126)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u4e1c\u5e08\u8303\u5927\u5b66",
#                     "value": 908,
#                     "textStyle": {
#                         "color": "rgb(51,77,105)"
#                     }
#                 },
#                 {
#                     "name": "\u590d\u65e6\u5927\u5b66",
#                     "value": 693,
#                     "textStyle": {
#                         "color": "rgb(140,137,133)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u5c71\u5927\u5b66",
#                     "value": 611,
#                     "textStyle": {
#                         "color": "rgb(80,158,23)"
#                     }
#                 },
#                 {
#                     "name": "\u5317\u4eac\u4e2d\u533b\u836f\u

# %% [markdown]
# ### 读取2021年考研调剂信息

# %%
import pandas as pd

# %%
df_info = pd.read_excel(r'./大学信息2021new.xlsx')
df_info.head()
# Out:
#         school school_type                                        school_attr  \
# 0       北方民族大学         民族类                             中央部委高校\n\n\n丝绸之路大学联盟成员
# 1  上海船舶运输科学研究所         NaN                                                NaN
# 2         北华大学          综合  （2012年）\n（2014年\n全国高校实践育人创新创业基地（2015年）\n（2017年...
# 3     佛山科学技术学院         NaN                                                NaN
# 4       武汉轻工大学          理工  国家粮食和物资储备局与湖北省人民政府共建高校（2018）\n湖北省国内一流学科建设高校（20...
#
#   province
# 0       宁夏
# 1       上海
# 2       吉林
# 3       广东
# 4       湖北

# %%
# !pip install openpyxl -i https://pypi.tuna.tsinghua.edu.cn/simple  --trusted-host pypi.tuna.tsinghua.edu.cn
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: openpyxl in c:\users\10942\appdata\local\anaconda3\lib\site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in c:\users\10942\appdata\local\anaconda3\lib\site-packages (from openpyxl) (1.1.0)

# %%
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       747 non-null    object
#  1   school_type  528 non-null    object
#  2   school_attr  531 non-null    object
#  3   province     747 non-null    object
# dtypes: object(4)
# memory usage: 23.5+ KB

# %% [markdown]
# ### 转换学校属性类别

# %%
def transform_attr(x):
    #转换学校属性
    if '211' in x and '985' not in x:
        return 211 
    elif '985' in x:
        return '985'
    else:
        return '双非'
    
def transform_type(x):
    #转换学校类型
    if '理工类' in x or '理工类院校' in x or '理工科' in x or '理工、教学研究型大学' in x or '理工类\n[4]' in x or '理工\n[6]' in x:
        return '理工'
    elif '综合类' in x or '综合性大学\n[3]' in x or '综合类（应用型大学）' in x or '综合、研究教学型大学' in x or '综合类大学' in x or '综合师范类' in x:
        return '综合'
    elif '师范类院校' in x or '师范类' in x or '师范类（综合类）' in x or '师范（综合）' in x or '地方师范院校' in x:
        return '师范'
    elif '农林类' in x or '农业类' in x: 
        return '农林'
    elif '医药类' in x:
        return '医药'
    elif '民族类' in x:
        return '民族'
    elif '未知' in x or '国有企业' in x or '科技型企业' in x or '公立大学' in x:
        return '其他'
    elif '重点' in x or '省' in x or '2' in x or '' in x:
        return '其他'
    else:
        return x 
    
# 转换数据
df_info['school_level'] = df_info.school_attr.astype(str).apply(lambda x:transform_attr(x))
df_info['school_types'] = df_info.school_type.astype(str).apply(lambda x: transform_type(x))
# 筛选字段
df_info= df_info[['school','province','school_level','school_types']]

# 处理省份数据
df_info.loc[(df_info.school=='北京工商大学')&(df_info.province=='未知'), 'province']= '北京' 
df_info.loc[(df_info.school=='哈尔滨工程大学')&(df_info.province=='未知'), 'province']= '哈尔滨' 
df_info.loc[(df_info.school=='江苏大学')&(df_info.province=='未知'), 'province']= '江苏' 
df_info.loc[(df_info.school=='青岛大学')&(df_info.province=='未知'), 'province']= '山东' 
df_info.loc[(df_info.school=='北京石油化工学院')&(df_info.province=='未知'), 'province']= '北京' 
df_info.loc[(df_info.school=='齐鲁工业大学')&(df_info.province=='未知'), 'province']= '山东'
df_info.loc[(df_info.school=='江苏科技大学')&(df_info.province=='未知'), 'province']= '江苏'
df_info.loc[(df_info.school=='浙江农林大学')&(df_info.province=='未知'), 'province']= '浙江'
df_info.loc[(df_info.school=='燕山大学')&(df_info.province=='未知'), 'province']= '河北'
df_info.loc[(df_info.school=='福州大学')&(df_info.province=='未知'), 'province']= '福建'
df_info.loc[(df_info.school=='内蒙古科技大学')&(df_info.province=='未知'), 'province']= '内蒙古'

# %%
df_info.head()
# Out:
#         school province school_level school_types
# 0       北方民族大学       宁夏           双非           民族
# 1  上海船舶运输科学研究所       上海           双非           其他
# 2         北华大学       吉林           双非           其他
# 3     佛山科学技术学院       广东           双非           其他
# 4       武汉轻工大学       湖北           双非           其他

# %% [markdown]
# ### 删除重复值

# %%
df_info = df_info.drop_duplicates()#删除重
df_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327 entries, 0 to 745
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   school        327 non-null    object
#  1   province      327 non-null    object
#  2   school_level  327 non-null    object
#  3   school_types  327 non-null    object
# dtypes: object(4)
# memory usage: 12.8+ KB

# %%
df_info.shape
# Out:
# (327, 4)

# %%
df = pd.read_excel(r'./考研调剂数据-3.08.xlsx')
df.shape
# Out:
# (747, 5)

# %%
df_2021 = df[df['time'].str.contains('2021')].copy()
df_2021.shape
# Out:
# (747, 5)

# %%
pd.merge(df_2021,df_info,how = 'left',on = 'school').shape
# Out:
# (774, 8)

# %% [markdown]
# ### 拼接调剂信息

# %%
df_all = pd.merge(df_2021,df_info,how = 'left',on = 'school')
df_all.head(5)
# Out:
#         school            name                          title  \
# 0       北方民族大学    电子科学与技术、电子信息  2021年北方民族大学“电子科学与技术”和“电子信息”..
# 1  上海船舶运输科学研究所  轮机工程、通信与信息系统..    上海船舶运输科学研究所2021年硕士研究生招生调剂信息
# 2         北华大学  基础数学、计算数学、概率..  北华大学数学与统计学院2021年硕士研究生招生预调剂信..
# 3     佛山科学技术学院  机械工程、光学工程、材料..     佛山科学技术学院2021年硕士研究生预调剂公告(一)
# 4     佛山科学技术学院  机械工程、光学工程、材料..     佛山科学技术学院2021年硕士研究生预调剂公告(一)
#
#                                    url        time province school_level  \
# 0  /tiaoji/schooldetail/id/28535.shtml  2021-03-09       宁夏           双非
# 1  /tiaoji/schooldetail/id/29191.shtml  2021-03-08       上海           双非
# 2  /tiaoji/schooldetail/id/29189.shtml  2021-03-08       吉林           双非
# 3  /tiaoji/schooldetail/id/29187.shtml  2021-03-08       广东           双非
# 4  /tiaoji/schooldetail/id/29187.shtml  2021-03-08       湖南           双非
#
#   school_types
# 0           民族
# 1           其他
# 2           其他
# 3           其他
# 4           其他

# %%
df_all = df_all[['school','name','time','province','school_level','school_types']]
df_all.head()
# Out:
#         school            name        time province school_level school_types
# 0       北方民族大学    电子科学与技术、电子信息  2021-03-09       宁夏           双非           民族
# 1  上海船舶运输科学研究所  轮机工程、通信与信息系统..  2021-03-08       上海           双非           其他
# 2         北华大学  基础数学、计算数学、概率..  2021-03-08       吉林           双非           其他
# 3     佛山科学技术学院  机械工程、光学工程、材料..  2021-03-08       广东           双非           其他
# 4     佛山科学技术学院  机械工程、光学工程、材料..  2021-03-08       湖南           双非           其他

# %% [markdown]
# ### 查看缺失数据

# %%
df_all.isnull().sum()
# Out:
# school           0
# name            10
# time             0
# province         0
# school_level     0
# school_types     0
# dtype: int64

# %% [markdown]
# ### 发布时间对应的发布频次

# %%
pub_time = df_all.time.value_counts().sort_index()
pub_time
# Out:
# time
# 2021-01-04      3
# 2021-01-05      1
# 2021-01-12      1
# 2021-01-19      2
# 2021-01-26      2
# 2021-02-05      1
# 2021-02-07      3
# 2021-02-18      6
# 2021-02-22      1
# 2021-02-23      3
# 2021-02-24      1
# 2021-02-25     14
# 2021-02-26    110
# 2021-02-27     64
# 2021-02-28     29
# 2021-03-01     78
# 2021-03-02     99
# 2021-03-03    101
# 2021-03-04     57
# 2021-03-05    108
# 2021-03-06     32
# 2021-03-07     12
# 2021-03-08     45
# 2021-03-09      1
# Name: count, dtype: int64

# %%
level_perc = df_all.school_level.value_counts() / df_all.school_level.value_counts().sum()
display(level_perc)
level_perc = np.round(level_perc * 100 ,2)
level_perc
# Out:
# school_level
# 双非     0.981912
# 985    0.011628
# 211    0.006460
# Name: count, dtype: float64
# school_level
# 双非     98.19
# 985     1.16
# 211     0.65
# Name: count, dtype: float64

# %% [markdown]
# ### 调剂信息发布时间走势图

# %%
line1 = Line(init_opts=opts.InitOpts(width='1000px',height='600px'))
line1.add_xaxis(pub_time.index.tolist())
line1.add_yaxis('发布热度',pub_time.values.tolist(),
               areastyle_opts=opts.AreaStyleOpts(opacity=0.5),
               label_opts=opts.LabelOpts(is_show=True))
line1.set_global_opts(title_opts=opts.TitleOpts(title='调剂信息发布时间走势图'),
                     toolbox_opts=opts.ToolboxOpts(),
                      xaxis_opts=opts.AxisOpts(name='时间',
                                               type_='category',                                           
                                               axislabel_opts=opts.LabelOpts(rotate=45),
                                               ),
                     visualmap_opts=opts.VisualMapOpts())
line1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="e1366e5ca7de417e9655efb9e591ef58" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_e1366e5ca7de417e9655efb9e591ef58 = echarts.init(
#                     document.getElementById('e1366e5ca7de417e9655efb9e591ef58'), 'white', {renderer: 'canvas'});
#                 var option_e1366e5ca7de417e9655efb9e591ef58 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u53d1\u5e03\u70ed\u5ea6",
#             "connectNulls": false,
#             "xAxisIndex": 0,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "2021-01-04",
#                     3
#                 ],
#                 [
#                     "2021-01-05",
#                     1
#                 ],
#                 [
#                     "2021-01-12",
#                     1
#                 ],
#                 [
#                     "2021-01-19",
#                     2
#                 ],
#                 [
#                     "2021-01-26",
#                     2
#                 ],
#                 [
#                     "2021-02-05",
#                     1
#                 ],
#                 [
#                     "2021-02-07",
#                     3
#                 ],
#                 [
#                     "2021-02-18",
#                     6
#                 ],
#                 [
#                     "2021-02-22",
#                     1
#                 ],
#                 [
#                     "2021-02-23",
#                     3
#                 ],
#                 [
#                     "2021-02-24",
#                     1
#                 ],
#                 [
#                     "2021-02-25",
#                     14
#                 ],
#                 [
#                     "2021-02-26",
#                     110
#                 ],
#                 [
#                     "2021-02-27",
#                     64
#                 ],
#                 [
#                     "2021-02-28",
#                     29
#                 ],
#                 [
#                     "2021-03-01",
#                     78
#                 ],
#                 [
#                     "2021-03-02",
#                     99
#                 ],
#                 [
#                     "2021-03-03",
#                     101
#                 ],
#                 [
#                     "2021-03-04",
#                     57
#                 ],
#                 [
#                     "2021-03-05",
#                     108
#                 ],
#                 [
#                     "2021-03-06",
#                     32
#                 ],
#                 [
#                     "2021-03-07",
#                     12
#                 ],
#                 [
#                     "2021-03-08",
#                     45
#                 ],
#                 [
#                     "2021-03-09",
#                     1
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "logBase": 10,
#             "seriesLayoutBy": "column",
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0.5
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53d1\u5e03\u70ed\u5ea6"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "name": "\u65f6\u95f4",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "rotate": 45,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2021-01-04",
#                 "2021-01-05",
#                 "2021-01-12",
#                 "2021-01-19",
#                 "2021-01-26",
#                 "2021-02-05",
#                 "2021-02-07",
#                 "2021-02-18",
#                 "2021-02-22",
#                 "2021-02-23",
#                 "2021-02-24",
#                 "2021-02-25",
#                 "2021-02-26",
#                 "2021-02-27",
#                 "2021-02-28",
#                 "2021-03-01",
#                 "2021-03-02",
#                 "2021-03-03",
#                 "2021-03-04",
#                 "2021-03-05",
#                 "2021-03-06",
#                 "2021-03-07",
#                 "2021-03-08",
#                 "2021-03-09"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u8c03\u5242\u4fe1\u606f\u53d1\u5e03\u65f6\u95f4\u8d70\u52bf\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVert

# %% [markdown]
# #### 由于考研成绩是在2月底发布的，所以调剂发布学校也随着增多

# %% [markdown]
# ### 绘制学校类别饼图

# %%
level_perc = df_all.school_level.value_counts() / df_all.school_level.value_counts().sum()
display(level_perc)
level_perc = np.round(level_perc * 100 ,2)
level_perc
# Out:
# school_level
# 双非     0.981912
# 985    0.011628
# 211    0.006460
# Name: count, dtype: float64
# school_level
# 双非     98.19
# 985     1.16
# 211     0.65
# Name: count, dtype: float64

# %%
pie1 = Pie(init_opts=opts.InitOpts(theme='light',width='800px',height='600px'))
pie1.add("", 
         [*zip(level_perc.index, level_perc.values)], 
         radius=["40%","75%"]) 
pie1.set_global_opts(title_opts=opts.TitleOpts(title='学校层次分布',pos_left='center', pos_top='center',title_textstyle_opts=opts.TextStyleOpts(
                                                   color='#00BFFF', font_size=30, font_weight='bold'),
                                               ), 
                     legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
#                      toolbox_opts=opts.ToolboxOpts()
                    )   
pie1.set_series_opts(label_opts=opts.LabelOpts(formatter="{c}%")) 
pie1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="62f08bfca4b940ad9de12872500427fa" style="width:800px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_62f08bfca4b940ad9de12872500427fa = echarts.init(
#                     document.getElementById('62f08bfca4b940ad9de12872500427fa'), 'light', {renderer: 'canvas'});
#                 var option_62f08bfca4b940ad9de12872500427fa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "pie",
#             "colorBy": "data",
#             "legendHoverLink": true,
#             "selectedMode": false,
#             "selectedOffset": 10,
#             "clockwise": true,
#             "startAngle": 90,
#             "minAngle": 0,
#             "minShowLabelAngle": 0,
#             "avoidLabelOverlap": true,
#             "stillShowZeroSum": true,
#             "percentPrecision": 2,
#             "showEmptyCircle": true,
#             "emptyCircleStyle": {
#                 "color": "lightgray",
#                 "borderColor": "#000",
#                 "borderWidth": 0,
#                 "borderType": "solid",
#                 "borderDashOffset": 0,
#                 "borderCap": "butt",
#                 "borderJoin": "bevel",
#                 "borderMiterLimit": 10,
#                 "opacity": 1
#             },
#             "data": [
#                 {
#                     "name": "\u53cc\u975e",
#                     "value": 98.19
#                 },
#                 {
#                     "name": "985",
#                     "value": 1.16
#                 },
#                 {
#                     "name": 211,
#                     "value": 0.65
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "margin": 8,
#                 "formatter": "{c}%"
#             },
#             "labelLine": {
#                 "show": true,
#                 "showAbove": false,
#                 "length": 15,
#                 "length2": 15,
#                 "smooth": false,
#                 "minTurnAngle": 90,
#                 "maxSurfaceAngle": 90
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u53cc\u975e",
#                 "985",
#                 211
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u5b66\u6821\u5c42\u6b21\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "left": "center",
#             "top": "center",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false,
#             "textStyle": {
#                 "color": "#00BFFF",
#                 "fontWeight": "bold",
#                 "fontSize": 30
#             }
#         }
#     ]
# };
#                 chart_62f08bfca4b940ad9de12872500427fa.setOption(option_62f08bfca4b940ad9de12872500427fa);
#         });
#     </script>

# %% [markdown]
# ### 调剂信息发布数省份分布

# %%
province_num = df_all.province.value_counts().sort_values()
province_num
# Out:
# province
# 贵州      2
# 宁夏      2
# 甘肃      4
# 海南      4
# 内蒙古     4
# 新疆      5
# 云南      6
# 天津     11
# 广西     14
# 安徽     18
# 河南     20
# 福建     20
# 四川     21
# 重庆     22
# 湖南     23
# 山西     24
# 江西     28
# 河北     30
# 吉林     32
# 浙江     33
# 辽宁     39
# 陕西     40
# 上海     41
# 江苏     45
# 黑龙江    46
# 湖北     48
# 广东     49
# 山东     64
# 北京     79
# Name: count, dtype: int64

# %%
# 条形图
bar3 = Bar(init_opts=opts.InitOpts(theme='light',width='1000px', height='1000px')) 
bar3.add_xaxis(province_num.index.tolist())
bar3.add_yaxis("省份", province_num.values.tolist()) 
bar3.set_global_opts(title_opts=opts.TitleOpts(title="调剂信息发布数省份分布"), 
#                      toolbox_opts=opts.ToolboxOpts(),
                     visualmap_opts=opts.VisualMapOpts(max_=79)) 
bar3.set_series_opts(label_opts=opts.LabelOpts(position='right'))  # 标签
bar3.reversal_axis() 
bar3.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="866da719d9b942b48452db10f2fb8104" style="width:1000px; height:1000px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_866da719d9b942b48452db10f2fb8104 = echarts.init(
#                     document.getElementById('866da719d9b942b48452db10f2fb8104'), 'light', {renderer: 'canvas'});
#                 var option_866da719d9b942b48452db10f2fb8104 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u7701\u4efd",
#             "legendHoverLink": true,
#             "data": [
#                 2,
#                 2,
#                 4,
#                 4,
#                 4,
#                 5,
#                 6,
#                 11,
#                 14,
#                 18,
#                 20,
#                 20,
#                 21,
#                 22,
#                 23,
#                 24,
#                 28,
#                 30,
#                 32,
#                 33,
#                 39,
#                 40,
#                 41,
#                 45,
#                 46,
#                 48,
#                 49,
#                 64,
#                 79
#             ],
#             "realtimeSort": false,
#             "showBackground": false,
#             "stackStrategy": "samesign",
#             "cursor": "pointer",
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7701\u4efd"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u8d35\u5dde",
#                 "\u5b81\u590f",
#                 "\u7518\u8083",
#                 "\u6d77\u5357",
#                 "\u5185\u8499\u53e4",
#                 "\u65b0\u7586",
#                 "\u4e91\u5357",
#                 "\u5929\u6d25",
#                 "\u5e7f\u897f",
#                 "\u5b89\u5fbd",
#                 "\u6cb3\u5357",
#                 "\u798f\u5efa",
#                 "\u56db\u5ddd",
#                 "\u91cd\u5e86",
#                 "\u6e56\u5357",
#                 "\u5c71\u897f",
#                 "\u6c5f\u897f",
#                 "\u6cb3\u5317",
#                 "\u5409\u6797",
#                 "\u6d59\u6c5f",
#                 "\u8fbd\u5b81",
#                 "\u9655\u897f",
#                 "\u4e0a\u6d77",
#                 "\u6c5f\u82cf",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u6e56\u5317",
#                 "\u5e7f\u4e1c",
#                 "\u5c71\u4e1c",
#                 "\u5317\u4eac"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "show": true,
#             "text": "\u8c03\u5242\u4fe1\u606f\u53d1\u5e03\u6570\u7701\u4efd\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 79,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_866da719d9b942b48452db10f2fb8104.setOption(option_866da719d9b942b48452db10f2fb8104);
#         });
#     </script>

# %%
c1 = Map(init_opts=opts.InitOpts(width='800px', height='750px'))
c1.add('',[list(z) for z in zip(province_num.index.tolist(), province_num.values.tolist())], 'china')
c1.set_global_opts(title_opts=opts.TitleOpts('调剂信息省份分布地图'), 
#                   toolbox_opts=opts.ToolboxOpts(is_show=True), 
                  visualmap_opts=opts.VisualMapOpts(max_=79)) 
c1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="182ae995b9694e6f92b94a1efb0cf591" style="width:800px; height:750px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_182ae995b9694e6f92b94a1efb0cf591 = echarts.init(
#                     document.getElementById('182ae995b9694e6f92b94a1efb0cf591'), 'white', {renderer: 'canvas'});
#                 var option_182ae995b9694e6f92b94a1efb0cf591 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 49
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 79
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": "\u8c03\u5242\u4fe1\u606f\u7701\u4efd\u5206\u5e03\u5730\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 79,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_182ae995b9694e6f92b94a1efb0cf591.setOption(option_182ae995b9694e6f92b94a1efb0cf591);
#         });
#     </script>

# %%
print([list(z) for z in zip(province_num.index.tolist(), province_num.values.tolist())])
# Out:
# [['贵州', 2], ['宁夏', 2], ['甘肃', 4], ['海南', 4], ['内蒙古', 4], ['新疆', 5], ['云南', 6], ['天津', 11], ['广西', 14], ['安徽', 18], ['河南', 20], ['福建', 20], ['四川', 21], ['重庆', 22], ['湖南', 23], ['山西', 24], ['江西', 28], ['河北', 30], ['吉林', 32], ['浙江', 33], ['辽宁', 39], ['陕西', 40], ['上海', 41], ['江苏', 45], ['黑龙江', 46], ['湖北', 48], ['广东', 49], ['山东', 64], ['北京', 79]]

# %%
# 改为省份全称才能正常显示
c2 = Map(init_opts=opts.InitOpts(width='800px', height='750px'))
c2.add('',[['贵州省', 2],
 ['宁夏回族自治区', 2],
 ['甘肃省', 4],
 ['海南省', 4],
 ['内蒙古自治区', 4],
 ['新疆维吾尔自治区', 5],
 ['云南省', 6],
 ['天津市', 11],
 ['广西壮族自治区', 14],
 ['安徽省', 18],
 ['河南省', 20],
 ['福建省', 20],
 ['四川省', 21],
 ['重庆市', 22],
 ['湖南省', 23],
 ['山西省', 24],
 ['江西省', 28],
 ['河北省', 30],
 ['吉林省', 32],
 ['浙江省', 33],
 ['辽宁省', 39],
 ['陕西省', 40],
 ['上海市', 41],
 ['江苏省', 45],
 ['黑龙江省', 46],
 ['湖北省', 48],
 ['广东省', 49],
 ['山东省', 64],
 ['北京市', 79]], 'china')
c2.set_global_opts(title_opts=opts.TitleOpts('调剂信息省份分布地图'), 
#                   toolbox_opts=opts.ToolboxOpts(is_show=True), 
                  visualmap_opts=opts.VisualMapOpts(max_=79)) 
c2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="95a050ba983147f689d8c871161cfe89" style="width:800px; height:750px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_95a050ba983147f689d8c871161cfe89 = echarts.init(
#                     document.getElementById('95a050ba983147f689d8c871161cfe89'), 'white', {renderer: 'canvas'});
#                 var option_95a050ba983147f689d8c871161cfe89 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": true,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u8d35\u5dde\u7701",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5b81\u590f\u56de\u65cf\u81ea\u6cbb\u533a",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u7518\u8083\u7701",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u6d77\u5357\u7701",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4\u81ea\u6cbb\u533a",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u4e91\u5357\u7701",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5929\u6d25\u5e02",
#                     "value": 11
#                 },
#                 {
#                     "name": "\u5e7f\u897f\u58ee\u65cf\u81ea\u6cbb\u533a",
#                     "value": 14
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u7701",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6cb3\u5357\u7701",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u798f\u5efa\u7701",
#                     "value": 20
#                 },
#                 {
#                     "name": "\u56db\u5ddd\u7701",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u91cd\u5e86\u5e02",
#                     "value": 22
#                 },
#                 {
#                     "name": "\u6e56\u5357\u7701",
#                     "value": 23
#                 },
#                 {
#                     "name": "\u5c71\u897f\u7701",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u6cb3\u5317\u7701",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u5409\u6797\u7701",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u8fbd\u5b81\u7701",
#                     "value": 39
#                 },
#                 {
#                     "name": "\u9655\u897f\u7701",
#                     "value": 40
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": 45
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f\u7701",
#                     "value": 46
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": 48
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": 49
#                 },
#                 {
#                     "name": "\u5c71\u4e1c\u7701",
#                     "value": 64
#                 },
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 79
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "zlevel": 0,
#             "z": 2,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": "\u8c03\u5242\u4fe1\u606f\u7701\u4efd\u5206\u5e03\u5730\u56fe",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 79,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_95a050ba983147f689d8c871161cfe89.setOption(option_95a050ba983147f689d8c871161cfe89);
#         });
#     </script>

# %%
from pyecharts.charts import Page
page = Page(layout=Page.DraggablePageLayout, page_title="历年考研分数大屏展示")

page.add(
   bar1,pie_chart,c,line1,pie1,bar3,c2)
# 先保存到test.html 然后打开，拖拽图片自定义布局， 之后记得点击左上角“save config”对布局文件进行保存。
# 会生成一个chart_config.json的文件，这其中包含了每个图表ID对应的布局位置
page.render('历年考研数据可视化大屏.html')
# Out:
# 'C:\\Users\\10942\\Desktop\\教育\\教育-历年考研分数线数据可视化\\历年考研数据可视化大屏.html'

# %%
from bs4 import BeautifulSoup
with open("历年考研数据可视化大屏.html", "r+", encoding='utf-8') as html:
    html_bf = BeautifulSoup(html, 'lxml')
    divs = html_bf.select('.chart-container') # 根据css定位标签，选中图像的父节点标签
    divs[0]["style"] = "width:600px;height:100px;position:absolute;top:0px;left:380px;border-style:dashed;border-color:#444444;border-width:0px;"
    divs[1]["style"] = "width:350px;height:270px;position:absolute;top:50px;left:30px;border-style:dashed;border-color:#444444;border-width:2px;"
    divs[2]["style"] = "width:400px;height:550px;position:absolute;top:50px;left:390px;border-style:dashed;border-color:#444444;border-width:2px;"
    divs[3]["style"] = "width:350px;height:270px;position:absolute;top:50px;left:800px;border-style:dashed;border-color:#444444;border-width:2px;"
    divs[4]["style"] = "width:350px;height:270px;position:absolute;top:330px;left:30px;border-style:dashed;border-color:#444444;border-width:2px;"
    divs[5]["style"] = "width:350px;height:270px;position:absolute;top:330px;left:800px;border-style:dashed;border-color:#444444;border-width:2px;"
    
    body = html_bf.find("body") # 根据标签名称定位到body标签
    body["style"] = "background-color:#00FFFF;" # 修改背景颜色
    html_new = str(html_bf) # 将BeautifulSoup对象转换为字符
    html.seek(0, 0) # 光标移动至
    html.truncate() # 删除光标后的所有字符内容
    html.write(html_new) # 将由BeautifulSoup对象转换得到的字符重新写入html文件
    html.close()
